# %%
#261
class stock:
    pass

# %%
#262
class stock:
    def __init__(self, name, code):
        self.name = name
        self.code = code

삼성 = stock("삼성전자", "005930")

print(삼성.name)
print(삼성.code)

# %%
#263
class stock:
    def __init__(self, name, code):
        self.name = name
        self.code = code

    def set_name(self, name):
        self.name = name

    
a = stock(None, None)
a.set_name("삼성전자")
print(a.name)
# Out:
# 삼성전자

# %%
#264
class stock:
    def __init__(self, name, code):
        self.name = name
        self.code = code

    def set_name(self, name):
        self.name = name
    
    def set_code(self, code):
        self.code = code

    
a = stock(None, None)
a.set_name("삼성전자")
print(a.name)
a.set_code("005930")
print(a.code)
# Out:
# 삼성전자
# 005930

# %%
#265
class stock:
    def __init__(self, name, code):
        self.name = name
        self.code = code

    def set_name(self, name):
        self.name = name
    
    def set_code(self, code):
        self.code = code

    def get_name(self):
        return self.name
    
    def get_code(self):
        return self.code

    
a = stock(None, None)
a.set_name("삼성전자")
print(a.name)
a.set_code("005930")
print(a.code)
print(a.get_name())
print(a.get_code())
# Out:
# 삼성전자
# 005930
# 삼성전자
# 005930

# %%
#266
class stock:
    def __init__(self, name, code, PER, PBR, 배당수익률):
        self.name = name
        self.code = code
        self.PER = PER
        self.PBR = PBR
        self.배당수익률 = 배당수익률

    def set_name(self, name):
        self.name = name
    
    def set_code(self, code):
        self.code = code

    def get_name(self):
        return self.name
    
    def get_code(self):
        return self.code

    
a = stock(None, None)
a.set_name("삼성전자")
print(a.name)
a.set_code("005930")
print(a.code)
print(a.get_name())
print(a.get_code())

# %%
#267
class stock:
    def __init__(self, name, code, PER, PBR, 배당수익률):
        self.name = name
        self.code = code
        self.PER = PER
        self.PBR = PBR
        self.배당수익률 = 배당수익률

    def set_name(self, name):
        self.name = name
    
    def set_code(self, code):
        self.code = code

    def get_name(self):
        return self.name
    
    def get_code(self):
        return self.code

    
a = stock("삼성전자", "005930", 15.79, 1.33, 2.83)
a.set_name("삼성전자")
print(a.name)
a.set_code("005930")
print(a.code)
print(a.get_name())
print(a.get_code())
# Out:
# 삼성전자
# 005930
# 삼성전자
# 005930

# %%
#268
class stock:
    def __init__(self, name, code, PER, PBR, dividend):
        self.name = name
        self.code = code
        self.PER = PER
        self.PBR = PBR
        self.dividend = dividend

    def set_name(self, name):
        self.name = name
    
    def set_code(self, code):
        self.code = code

    def set_per(self, PER):
        self.PER = PER
    
    def set_pbr(self, PBR):
        self.PBR = PBR

    def set_dividend(self, dividend):
        self.did = dividend

    def get_name(self):
        return self.name
    
    def get_code(self):
        return self.code

    
a = stock("삼성전자", "005930", 15.79, 1.33, 2.83)
a.set_name("삼성전자")
print(a.name)
a.set_code("005930")
print(a.code)
print(a.get_name())
print(a.get_code())

# %%
#269
class stock:
    def __init__(self, name, code, PER, PBR, dividend):
        self.name = name
        self.code = code
        self.PER = PER
        self.PBR = PBR
        self.dividend = dividend

    def set_name(self, name):
        self.name = name
    
    def set_code(self, code):
        self.code = code

    def set_per(self, PER):
        self.PER = PER
    
    def set_pbr(self, PBR):
        self.PBR = PBR

    def set_dividend(self, dividend):
        self.did = dividend

    def get_name(self):
        return self.name
    
    def get_code(self):
        return self.code

    
a = stock("삼성전자", "005930", 15.79, 1.33, 2.83)
a.set_per(12.75)
print(a.PER)
# Out:
# 12.75

# %%
#270
event = []
class stock:
    def __init__(self, name, code, PER, PBR, dividend):
        self.name = name
        self.code = code
        self.PER = PER
        self.PBR = PBR
        self.dividend = dividend

    def set_name(self, name):
        self.name = name
    
    def set_code(self, code):
        self.code = code

    def set_per(self, PER):
        self.PER = PER
    
    def set_pbr(self, PBR):
        self.PBR = PBR

    def set_dividend(self, dividend):
        self.did = dividend

    def get_name(self):
        return self.name
    
    def get_code(self):
        return self.code

    
SM = stock("삼성전자", "005930", 15.79, 1.33, 2.83)
HD = stock("현대차", "005380", 8.70, 0.35, 4.27)
LG = stock("LG전자", "066570", 317.34, 0.69, 1.37)

event.append(SM)
event.append(HD)
event.append(LG)

for i in event:
    print(i.code, i.PER)
# Out:
# 005930 15.79
# 005380 8.7
# 066570 317.34

# %%
#271
import random

class Account:
    def __init__(self, name, balance):
        self.name = name 
        self.balance = balance
        self.bank = "SC은행"
        num1 = random.randint(0, 999)
        num2 = random.randint(0, 99)
        num3 = random.randint(0, 999999)

        num1 = str(num1).zfill(3)
        num2 = str(num2).zfill(2)
        num3 = str(num3).zfill(6)

        self.account_number = num1 + '-' + num2 + '-' + num3

acname = Account("이민혁", 10000)
print(acname.name)
print(acname.balance)
print(acname.bank)
print(acname.account_number)
# Out:
# 이민혁
# 10000
# SC은행
# 712-90-984629

# %%
#271
import random

class Account:
    def __init__(self, name, balance):
        self.name = name 
        self.balance = balance
        self.bank = "SC은행"
        num1 = random.randint(0, 999)
        num2 = random.randint(0, 99)
        num3 = random.randint(0, 999999)

        num1 = str(num1).zfill(3)
        num2 = str(num2).zfill(2)
        num3 = str(num3).zfill(6)

        self.account_number = num1 + '-' + num2 + '-' + num3

   

acname1 = Account("이민혁", 10000)
print(acname.name)
print(acname.balance)
print(acname.bank)
print(acname.account_number)

# %%
#272
import random

class Account:
    account_count = 0
    def __init__(self, name, balance):
        self.name = name 
        self.balance = balance
        self.bank = "SC은행"
        num1 = random.randint(0, 999)
        num2 = random.randint(0, 99)
        num3 = random.randint(0, 999999)

        num1 = str(num1).zfill(3)
        num2 = str(num2).zfill(2)
        num3 = str(num3).zfill(6)

        self.account_number = num1 + '-' + num2 + '-' + num3

        Account.account_count += 1

acname1 = Account("이민혁", 10000)
print(Account.account_count)
acname2 = Account("이민승", 1000)
print(Account.account_count)
# Out:
# 1
# 2

# %%
#273
import random

class Account:
    account_count = 0
    def __init__(self, name, balance):
        self.name = name 
        self.balance = balance
        self.bank = "SC은행"
        num1 = random.randint(0, 999)
        num2 = random.randint(0, 99)
        num3 = random.randint(0, 999999)

        num1 = str(num1).zfill(3)
        num2 = str(num2).zfill(2)
        num3 = str(num3).zfill(6)

        self.account_number = num1 + '-' + num2 + '-' + num3

        Account.account_count += 1

    @classmethod
    def get_account_num(cls):
        print(cls.account_count)


acname1 = Account("이민혁", 10000)
print(Account.account_count)
acname2 = Account("이민승", 1000)
print(Account.account_count)
acname1.get_account_num()
# Out:
# 1
# 2

# %%
#274
import random

class Account:
    account_count = 0
    def __init__(self, name, balance):
        self.name = name 
        self.balance = balance
        self.bank = "SC은행"
        num1 = random.randint(0, 999)
        num2 = random.randint(0, 99)
        num3 = random.randint(0, 999999)

        num1 = str(num1).zfill(3)
        num2 = str(num2).zfill(2)
        num3 = str(num3).zfill(6)

        self.account_number = num1 + '-' + num2 + '-' + num3

        Account.account_count += 1

    @classmethod
    def get_account_num(cls):
        print(cls.account_count)     

    def deposit(self, amount):
        if amount >= 1:
            self.balance += amount


acname1 = Account("이민혁", 10000)
print(Account.account_count)
acname2 = Account("이민승", 1000)
print(Account.account_count)

# %%
#275
import random

class Account:
    account_count = 0
    def __init__(self, name, balance):
        self.name = name 
        self.balance = balance
        self.bank = "SC은행"
        num1 = random.randint(0, 999)
        num2 = random.randint(0, 99)
        num3 = random.randint(0, 999999)

        num1 = str(num1).zfill(3)
        num2 = str(num2).zfill(2)
        num3 = str(num3).zfill(6)

        self.account_number = num1 + '-' + num2 + '-' + num3

        Account.account_count += 1

    @classmethod
    def get_account_num(cls):
        print(cls.account_count)  

    def deposit(self, amount):
        if amount >= 1:
            self.balance += amount

    def withdraw(self, amount):
        if self.balance > amount:
            self.balance -= amount


acname1 = Account("이민혁", 10000)
print(Account.account_count)
acname2 = Account("이민승", 1000)
print(Account.account_count)
acname1.deposit(100)
acname1.withdraw(90)
print(acname1.balance)
# Out:
# 1
# 2
# 10010

# %%
#276
import random

class Account:
    account_count = 0
    def __init__(self, name, balance):
        self.name = name 
        self.balance = balance
        self.bank = "SC은행"
        num1 = random.randint(0, 999)
        num2 = random.randint(0, 99)
        num3 = random.randint(0, 999999)

        num1 = str(num1).zfill(3)
        num2 = str(num2).zfill(2)
        num3 = str(num3).zfill(6)

        self.account_number = num1 + '-' + num2 + '-' + num3

        Account.account_count += 1

    @classmethod
    def get_account_num(cls):
        print(cls.account_count)  

    def deposit(self, amount):
        if amount >= 1:
            self.balance += amount

    def withdraw(self, amount):
        if self.balance > amount:
            self.balance -= amount
    
    def display_info(self):
        print("은행이름: ", self.bank)
        print("예금주: ", self.name)
        print("계좌번호: ", self.account_number)
        print("잔고: ", self.balance)

a = Account("파이썬", 10000)
a.display_info()
# Out:
# 은행이름:  SC은행
# 예금주:  파이썬
# 계좌번호:  089-88-725541
# 잔고:  10000

# %%
#277
import random

class Account:
    account_count = 0
    def __init__(self, name, balance):
        self.deposit_count = 0
        self.name = name 
        self.balance = balance
        self.bank = "SC은행"
        num1 = random.randint(0, 999)
        num2 = random.randint(0, 99)
        num3 = random.randint(0, 999999)

        num1 = str(num1).zfill(3)
        num2 = str(num2).zfill(2)
        num3 = str(num3).zfill(6)

        self.account_number = num1 + '-' + num2 + '-' + num3

        Account.account_count += 1

    @classmethod
    def get_account_num(cls):
        print(cls.account_count)  # Account.account_count

    def deposit(self, amount):
        if amount >= 1:
            self.balance += amount

            self.deposit_count += 1
            if self.deposit_count % 5 == 0:         # 5, 10, 15
                # 이자 지금
                self.balance = (self.balance * 1.01)


    def withdraw(self, amount):
        if self.balance > amount:
            self.balance -= amount

    def display_info(self):
        print("은행이름: ", self.bank)
        print("예금주: ", self.name)
        print("계좌번호: ", self.account_number)
        print("잔고: ", self.balance)

a = Account("파이썬", 10000)
a.deposit(10000)
a.deposit(10000)
a.deposit(10000)
a.deposit(5000)
a.deposit(5000)
print(a.balance)
# Out:
# 50500.0

# %%
#278
import random

class Account:
    account_count = 0
    def __init__(self, name, balance):
        self.deposit_count = 0
        self.name = name 
        self.balance = balance
        self.bank = "SC은행"
        num1 = random.randint(0, 999)
        num2 = random.randint(0, 99)
        num3 = random.randint(0, 999999)

        num1 = str(num1).zfill(3)
        num2 = str(num2).zfill(2)
        num3 = str(num3).zfill(6)

        self.account_number = num1 + '-' + num2 + '-' + num3

        Account.account_count += 1

    @classmethod
    def get_account_num(cls):
        print(cls.account_count) 

    def deposit(self, amount):
        if amount >= 1:
            self.balance += amount

            self.deposit_count += 1
            if self.deposit_count % 5 == 0:         
                self.balance = (self.balance * 1.01)


    def withdraw(self, amount):
        if self.balance > amount:
            self.balance -= amount

    def display_info(self):
        print("은행이름: ", self.bank)
        print("예금주: ", self.name)
        print("계좌번호: ", self.account_number)
        print("잔고: ", self.balance)

data = []
k = Account("KIM", 10000000)
l = Account("LEE", 10000)
p = Account("PARK", 10000)

data.append(k)
data.append(l)
data.append(p)

print(data)
# Out:
# [<__main__.Account object at 0x7f9558ebc7f0>, <__main__.Account object at 0x7f9558ebc550>, <__main__.Account object at 0x7f9558ebc520>]

# %%
#279
import random

class Account:
    account_count = 0
    def __init__(self, name, balance):
        self.deposit_count = 0
        self.name = name 
        self.balance = balance
        self.bank = "SC은행"
        num1 = random.randint(0, 999)
        num2 = random.randint(0, 99)
        num3 = random.randint(0, 999999)

        num1 = str(num1).zfill(3)
        num2 = str(num2).zfill(2)
        num3 = str(num3).zfill(6)

        self.account_number = num1 + '-' + num2 + '-' + num3

        Account.account_count += 1

    @classmethod
    def get_account_num(cls):
        print(cls.account_count) 

    def deposit(self, amount):
        if amount >= 1:
            self.balance += amount

            self.deposit_count += 1
            if self.deposit_count % 5 == 0:         
                self.balance = (self.balance * 1.01)


    def withdraw(self, amount):
        if self.balance > amount:
            self.balance -= amount

    def display_info(self):
        print("은행이름: ", self.bank)
        print("예금주: ", self.name)
        print("계좌번호: ", self.account_number)
        print("잔고: ", self.balance)

data = []
acname1 = Account("이민혁", 10000000)
acname2 = Account("이민승", 10000)
acname3 = Account("김준성", 10000)

data.append(acname1)
data.append(acname2)
data.append(acname3)

print(data)

for c in data:
    if c.balance >= 1000000:
        c.display_info()
# Out:
# [<__main__.Account object at 0x7f9558eb8340>, <__main__.Account object at 0x7f9558eb8d30>, <__main__.Account object at 0x7f9558eb8ca0>]
# 은행이름:  SC은행
# 예금주:  이민혁
# 계좌번호:  470-15-690428
# 잔고:  10000000

# %%
#280
import random

class Account:
    account_count = 0
    def __init__(self, name, balance):
        self.deposit_count = 0
        self.deposit_log = []
        self.withdraw_log = []
        self.name = name 
        self.balance = balance
        self.bank = "SC은행"
        num1 = random.randint(0, 999)
        num2 = random.randint(0, 99)
        num3 = random.randint(0, 999999)

        num1 = str(num1).zfill(3)
        num2 = str(num2).zfill(2)
        num3 = str(num3).zfill(6)

        self.account_number = num1 + '-' + num2 + '-' + num3

        Account.account_count += 1

    @classmethod
    def get_account_num(cls):
        print(cls.account_count) 

    def deposit(self, amount):
        if amount >= 1:
            self.balance += amount

            self.deposit_count += 1
            if self.deposit_count % 5 == 0:         
                self.balance = (self.balance * 1.01)


    def withdraw(self, amount):
        if self.balance > amount:
            self.balance -= amount

    def display_info(self):
        print("은행이름: ", self.bank)
        print("예금주: ", self.name)
        print("계좌번호: ", self.account_number)
        print("잔고: ", self.balance)
    
    def withdraw_history(self):
        for amount in self.withdraw_log:
            print(amount)

    def deposit_history(self):
        for amount in self.deposit_log:
            print(amount)


acname1 = Account("이민혁", 1000)
acname1.deposit(100)
acname1.deposit(200)
acname1.deposit(300)
acname1.deposit_history()

acname1.withdraw(100)
acname1.withdraw(200)
acname1.withdraw_history()
